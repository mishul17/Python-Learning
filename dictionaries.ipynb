# %% [markdown]
# ## Dictionaries

# %% [markdown]
# #### Introduction to Dictionaries

# %% [markdown]
# Dictionaries are unordered collections of items. They store data in key-value pairs. Keys must be unique and immutable(e.g., Strings, numbers, tuples), while values can be of any type.

# %%
## Creating Dictionaies
empty_dict={}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict=dict()
empty_dict
# Out:
# {}

# %%
student={"name": "Mishul","age":23,"grade":24}
print(student)
# Out:
# {'name': 'Mishul', 'age': 23, 'grade': 24}

# %%
## Error  (Single key is always used)
student={"name": "Mishul","age":23,"name":24}
print(student)
# Out:
# {'name': 24, 'age': 23}

# %%
## Accessing dictionary elements
student={"name": "Mishul","age":23,"grade":'A'}
print(student)
# Out:
# {'name': 'Mishul', 'age': 23, 'grade': 'A'}

# %%
##Accessing dictionary elements 
print(student['grade'])
print(student['age'])

## Accessing using get() method
print(student.get('grade'))
print(student.get('last_name')) 
print(student.get('last_name',"Not Available"))
# Out:
# A
# 23
# A
# None
# Not Available

# %%
## Modifying dictionary elements
## Dictionary are mutable, so you can add, update or delete elements
print(student)
# Out:
# {'name': 'Mishul', 'age': 23, 'grade': 'A'}

# %%
student["age"]=24  ## Update value for the key
print(student)
student["address"]="India"  ## Added a new key and value
print(student)
# Out:
# {'name': 'Mishul', 'age': 24, 'grade': 'A'}
# {'name': 'Mishul', 'age': 24, 'grade': 'A', 'address': 'India'}

# %%
del student['grade']  ## Delete key and value pair
print(student)
# Out:
# {'name': 'Mishul', 'age': 24, 'address': 'India'}

# %%
## Dictionary Methods

keys=student.keys()   ## get all the keys
print(keys)
values=student.values()   ## get all values
print(values)


items=student.items()  ## get all key value pairs
print(items)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['Mishul', 24, 'India'])
# dict_items([('name', 'Mishul'), ('age', 24), ('address', 'India')])

# %%
## Shallow copy
student_copy=student
print(student)
print(student_copy)
# Out:
# {'name': 'Mishul', 'age': 24, 'address': 'India'}
# {'name': 'Mishul', 'age': 24, 'address': 'India'}

# %%
student["name"]="Mishul1"
print(student)
print(student_copy)
# Out:
# {'name': 'Mishul1', 'age': 24, 'address': 'India'}
# {'name': 'Mishul1', 'age': 24, 'address': 'India'}

# %%
student_copy1=student.copy()  ## shallow copy
print(student_copy1)
print(student)
# Out:
# {'name': 'Mishul1', 'age': 24, 'address': 'India'}
# {'name': 'Mishul1', 'age': 24, 'address': 'India'}

# %%
student["name"]="Mishul3"
print(student_copy1)
print(student)
# Out:
# {'name': 'Mishul1', 'age': 24, 'address': 'India'}
# {'name': 'Mishul3', 'age': 24, 'address': 'India'}

# %%
## Iterating over dictionaries
## You can use loops to iterate over dictionaries, keys, values, or items

## Iterating over keys 

for keys in student.keys():
    print(keys)
# Out:
# name
# age
# address

# %%
## Iterate over values
for values in student.values():
    print(values)
# Out:
# Mishul3
# 24
# India

# %%
## Iterate over key value pairs
for key,value in student.items():
    print(f"{key}:{value}")
# Out:
# name:Mishul3
# age:24
# address:India

# %%
## Nested Dictionaries
students={
    "student1":{"name":"Mishul","age":23},
    "student2":{"name":"Conrad","age":25}
}
print(students)
# Out:
# {'student1': {'name': 'Mishul', 'age': 23}, 'student2': {'name': 'Conrad', 'age': 25}}

# %%
## Access nested dictionaries elements
print(students["student2"]["name"])
print(students["student2"]["age"])
# Out:
# Conrad
# 25

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'Mishul', 'age': 23}), ('student2', {'name': 'Conrad', 'age': 25})])

# %%
## Iterating over nested dictionaries
for student_id, student_info in students.items():
    print(f"{student_id}:{student_info}")
    for key,value in student_info.items():
        print(f"{key}:{value}")
# Out:
# student1:{'name': 'Mishul', 'age': 23}
# name:Mishul
# age:23
# student2:{'name': 'Conrad', 'age': 25}
# name:Conrad
# age:25

# %%
## Dictionary Comprehension

squares={x:x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
## Conditional dictionary comprehension
evens={x:x**2 for x in range(10) if x%2==0}
print(evens)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
## Practical Examples

## Use a dictionary to count the frequency of element in list

numbers=[1,2,2,3,3,3,4,4,4,4]
frequency={}

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %%
## Merge two dictionary into one

dict1={"a":1,"b":2}
dict2={"b":3,"c":4}
merged_dict={**dict1,**dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
