# %% [markdown]
# # Module 3: Data Structure Assignment

# %% [markdown]
# ## Lesson 3.1 : Lists

# %% [markdown]
# #### Assignment 1: Creating and Accessing List

# %% [markdown]
# Create a list of the first 20 positive integers. Print the list.
