# %%
##Integer examples
age=35
type(age)
# Out:
# int

# %%
##floating point datatype
height=5.11
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
##string datatype
name="mishul"
print(name)
print(type(name))
# Out:
# mishul
# <class 'str'>

# %%
## boolean datatype
print(type(True))
# Out:
# <class 'bool'>

# %%
a=10
b=10
type(a==b)
# Out:
# bool
